# %%
import os
os.chdir("c:")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Titanic_Survival_Prediction_Project\tested.csv")
df.head(418)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# performing EDA on dataset

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# as number of filling values is more we have to handle them -- if missing values are less we can drop that cell 
#handeling age missing data with fillna 
#Dropping cabin column as its very time consuming to impute correct cabin numbers and deck number

# %%
df['Age'].fillna(df['Age'].median(),inplace = True)
df['Fare'].fillna(df['Fare'].median(),inplace = True)
df.drop('Cabin',axis = 1,inplace = True)

# %%
#As the dataset is now clean and Has been Handeled with Missing data using Fillna function
#Start the Exploratory Data Analysis

# %% [markdown]
# Steps to do in EDA
# Univariate Analysis
# Bivariate Analysis
# Correlation Heatmaps for Numerical Features

# %%
sns.countplot(x='Survived',hue='Sex',data = df)
plt.title("Survival By Sex")
plt.show()

# %%
sns.countplot(x='Survived', data = df)
plt.title("Total Survival Counts")
plt.show()

# %%
sns.countplot(x='Survived',hue=df['Pclass'].astype(str),data = df)
plt.title("Survival By Class")
plt.show()

# %%
#Correlation Heatmap
numeric = df.select_dtypes(['int64','float64'])

# %%
plt.figure(figsize = (12,6))
sns.heatmap(numeric,annot = True)
cmap = ("coolwarm")
plt.title("Correlation Heatmap")
plt.show()
